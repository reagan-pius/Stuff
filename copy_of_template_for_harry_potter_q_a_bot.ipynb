# %% [markdown]
# <a href="https://colab.research.google.com/github/reagan-pius/Stuff/blob/main/copy_of_template_for_harry_potter_q_a_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1: Import the necessary libraries, such as transformers, nltk, spacy, etc.

# %%
# import transformers
# import nltk
# import spacy
# import pandas as pd

# %% [markdown]
# #### Testing 1

# %% [markdown]
# Importing necessary libraries

# %%
# importing trandformers and datasets libraries
# !pip install -q transformers datasets

# importing load_dataset to help load our model later
from datasets import load_dataset

# autoTokenizer to convert text data to tokens
from transformers import AutoTokenizer
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 15.0.0 which is incompatible.

# %% [markdown]
# Loading the HP dataset from hugging face

# %%
dataset = load_dataset("WutYee/HarryPotter_books_1to7")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
print(dataset)    # to see what the dataset contains
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 81349
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 23118
#     })
#     test: Dataset({
#         features: ['text'],
#         num_rows: 23620
#     })
# })

# %%
# the dataset hold train, val, and test dsets, with only text

inspecting = dataset['train'] # lets get the keys in the train dict

print(inspecting)
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 81349
# })

# %%
harry_potter_context = dataset['train']['text']  # set all the text in the train ds as context

# print(harry_potter_context)

# %% [markdown]
# Preprocessing

# %%
# we imported autotokenizer already so we just proceed

tokenizer = AutoTokenizer.from_pretrained("deepset/bert-base-cased-squad2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/152 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/508 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
# now calling the tokenizer on only the first row of our dataset
"""
returns model inputs;
input_ids: the numbers representing the tokens in the text.
token_type_ids: indicates which sequence a token belongs to if there is more than one sequence.
attention_mask: indicates whether a token should be masked or not.

"""
tokenizer(harry_potter_context[0])
# Out:
# {'input_ids': [101, 18444, 122, 118, 3466, 11434, 1105, 1103, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1]}

# %%
# now we can tokenizing the whole dataset with a map() function and an example line from Harry Porter book to speed up the process

example = "usual amount of neck, which came in very useful as she spent so much of her"

def tokenization(example):
  return tokenizer(example["text"])

dataset = dataset.map(tokenization, batched = True)
# Out:
# ...
# Map:   0%|          | 0/23620 [00:00<?, ? examples/s]

# %%
# next is formating the tokens to match either Tensorflow or Pytorch framework
# I chose Pytorch
"""
Bummer: I can't seem to proceed due to an attribute conflict: see Error Message
TO DO: Read about Spacy to see if I can work around the error https://pytorch.org/tutorials/beginner/torchtext_custom_dataset_tutorial.html
"""

dataset.set_format(type="torch", columns=["input_ids", "token_type_ids", "attention_mask", "text"])
dataset.format['type']

ds = ds.map(lambda x: tokenizer(x['text'], truncation=True, padding=True), batched=True)
ds.set_format(type='numpy', columns=['text', 'label'])
ds.format
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-bf8f031ca328> in <cell line: 9>()
#       7
#       8 dataset.set_format(type="torch", columns=["input_ids", "token_type_ids", "attention_mask", "text"])
# ----> 9 dataset.format['type']
#      10
#      11 ds = ds.map(lambda x: tokenizer(x['text'], truncation=True, padding=True), batched=True)
#
# AttributeError: 'DatasetDict' object has no attribute 'format'

# %% [markdown]
# # Step 2: Load the Harry Potter dataset from Kaggle or other sources

# %%
# loading the dataset actually happened two days ago

# %% [markdown]
# # Step 3: Preprocess the data, such as tokenising, cleaning, etc.

# %% [markdown]
# # Step 4: Choose a pre-trained language model, such as GPT-3.5 or BERT, and fine-tune it on the Harry Potter data

# %% [markdown]
# # Step 5: Define the question processing function, which takes user input and returns a question

# %% [markdown]
# # Step 6: Define the context understanding function, which uses NLP and LLMs to analyse the question and find the relevant context

# %% [markdown]
# # Step 7: Define the answer generation function, which uses the context and the language model to generate an answer

# %% [markdown]
# # Step 8: Define the error handling function, which provides feedback to the user when the question is invalid or the answer is not found

# %% [markdown]
# # Step 9: Create a simple and intuitive user interface, such as a chatbot window, for users to interact with the bot

# %% [markdown]
# # Step 10: Test the bot on various questions and edge cases, and evaluate its performance and accuracy

# %% [markdown]
# # Step 11: Deploy the bot on a platform, such as a website, a mobile app, or a platform like Slack or Discord
